# %% [markdown]
# # 3D Plots in Matplotlib
#
# Matplotlib supports 3D plotting through the `mpl_toolkits.mplot3d` module. In this section, we'll cover:
# - 3D Line Plots
# - 3D Scatter Plots
# - 3D Surface Plots

# %% [markdown]
# ## 3D Line Plot
# Use `Axes3D` to create 3D line plots.

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
t = np.linspace(0, 20, 100)
x = np.sin(t)
y = np.cos(t)
z = t
ax.plot(x, y, z)
ax.set_title('3D Line Plot')
plt.show()

# %% [markdown]
# ## 3D Scatter Plot
# Use `scatter` for 3D scatter plots.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
x = np.random.rand(100)
y = np.random.rand(100)
z = np.random.rand(100)
ax.scatter(x, y, z, c=z, cmap='viridis')
ax.set_title('3D Scatter Plot')
plt.show()

# %% [markdown]
# ## 3D Surface Plot
# Use `plot_surface` for 3D surfaces.

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
X = np.linspace(-5, 5, 50)
Y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))
surf = ax.plot_surface(X, Y, Z, cmap='viridis')
fig.colorbar(surf)
ax.set_title('3D Surface Plot')
plt.show()

# %% [markdown]
# ## Summary
# - Use `mpl_toolkits.mplot3d` for 3D plots.
# - Create line, scatter, and surface plots in 3D.
#
# Next, we'll explore interactive plotting.
