# %% [markdown]
# # Class Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {

    "Name":["Dhruval","Amogh","Om","Kanika","Kartik","Nirlipta"],
    "Marks":[90, 85, 92, 88, 95, 91]

}

df = pandas.DataFrame(data)

# %%
plt.bar(df["Name"], df["Marks"])
plt.title("Marks of Students")
plt.xlabel("Names")
plt.ylabel("Marks")
plt.show()

# %%
plt.plot(df["Name"], df["Marks"], marker='o')
plt.title("Marks of Students")
plt.show()

# %%
plt.hist(df["Marks"], bins=5, edgecolor='black')
plt.title("Distribution of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
new_data = {
    'Name': ['Dhruval', 'Mahek', 'Neem', 'Daksh', 'Suhani'],
    'Age': [20,19,19,19,18],
    'Salary': [80000,85000,75000,69999,78000]
}

df = pd.DataFrame(new_data)

# %%
plt.scatter(df["Name"], df["Salary"])
plt.title("Salary vs Name")
plt.xlabel("Name")
plt.ylabel("Salary")
plt.show()

# %%
plt.plot(df["Name"], df["Salary"], marker='o')
plt.title("Salary vs Name")
plt.xlabel("Friends")
plt.ylabel("Salary")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
