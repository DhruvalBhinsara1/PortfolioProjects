# %%
A = 'HI'

print(A+1)

# %%
A = [4,5,6]
Y = [7,8,9]

print(A+Y)

# %%
A = 'HI'
Y = 6
print(A*Y, end=" ")

# %%
A = 'HI'
B = 'HI'

print(A*B)

# %%
A = (12,3,4)
B= (2,3,4)

print(A*B)

# %%
from tokenize import String


A = int(input("Enter a value"))

print(A)

A = bool(input("Enter a value"))

print(A)

A = float(input("Enter a value"))

print(A)

# %%
nums = [0,0,1,1,1,2,2,3,3,4]

nums2 = []

for i in nums:
    if i not in nums2:
        nums2.append(i)

nums = nums2

print(nums)
# Out:
# [0, 1, 2, 3, 4]

# %%
nums = [0,0,1,1,1,2,2,3,3,4]
nums_no_duplicates = list(set(nums))
print(nums_no_duplicates)
# Out:
# [0, 1, 2, 3, 4]

# %%
nums = [1,1,2]


nums = [1,1,2,3,4,4,4,5]

print(nums)
            
nums2 = []

for i in nums:

    if i not in nums2:
        nums2.append(i)

nums = nums2

print(nums)
# Out:
# [1, 1, 2, 3, 4, 4, 4, 5]
# [1, 2, 3, 4, 5]

# %%
k = 3

arr = [1,2,3,4,5]

print(arr)

arr= arr[::-k]

print(arr)

arr[k::]

print(arr)
# Out:
# [1, 2, 3, 4, 5]
# [5, 2]
# [5, 2]

# %%
nums = [1,2,3,4,5,6,7]


def rotate (nums , k):
    length = len(nums)

    k = k % length

    nums[:] = nums[-k:] + nums[:-k]

    #nums[:] = nums[-k:] + nums[::-k]

rotate(nums,k)


print(nums)
# Out:
# [5, 6, 7, 1, 2, 3, 4]

# %%
#two sum

nums = [2,7,11,15]


def twoSum(nums, target):
    num_map = {}
    for i, num in enumerate(nums):
        complement = target - num
        if complement in num_map:
            return [num_map[complement], i]
        num_map[num] = i
    return []


print(twoSum(nums,9))
# Out:
# [0, 1]

# %%
def removeDuplicates(nums):
    if not nums:
        return 0, []

    write_index = 1

    for read_index in range(1, len(nums)):
        if nums[read_index] != nums[read_index - 1]:
            nums[write_index] = nums[read_index]
            write_index += 1

    return write_index, nums[:write_index]

nums = [1,1,2]
k, deduped = removeDuplicates(nums)
print(k)        # 5
print(deduped)  # [0, 1, 2, 3, 4]
# Out:
# 2
# [1, 2]

# %%
nums = [0,1,0,3,12]

write = 0

print(write)

for read in range(len(nums)):
    if nums[read] != 0:
        nums[write] = nums[read]
        write += 1
        print(nums)
        print(write)
        print(read)

for i in range(write, len(nums)):
    nums[i] = 0


print(nums)
# Out:
# 0
# [1, 1, 0, 3, 12]
# 1
# 1
# [1, 3, 0, 3, 12]
# 2
# 3
# [1, 3, 12, 3, 12]
# 3
# 4
# [1, 3, 12, 0, 0]

# %%
def print_numbers(n):
    if n < 10:
        return
    print(n)
    print_numbers(n - 1)

print_numbers(10)
# Out:
# 10

# %%
for i in range(10,-1,0-3):
    print(i)
# Out:
# 10
# 7
# 4
# 1

# %%
arr= [1,4,8,9,10]

print(arr[2:5])
# Out:
# [8, 9, 10]

# %%
x = "str"

print(x.isalpha())
# Out:
# True

# %%
x1 = "str1"

print(x.isalnum())
# Out:
# True

# %%
x = [1,32,3,3,1]

print(x.index(3))
# Out:
# 2

# %%
x = [1,32,3,321,32,21,3,1]


for i in range(len(x)):
    if x[i] == 21:
        print(i)
# Out:
# 5

# %%
list1 = [1,3,4,6,7]

list1.sort()

def check_num(list1):
    for i in range(len(list1)-1):
        if list1[i] <= list1[i+1]:
            print(True)
# Out:
# True
# True
# True
# True

# %%
nums = [1,1,3,4,5]

#two sum II - input Array is sorted

def twoSumII(nums, target):
    left = 0
    right = len(nums) - 1

    while left < right:
        current_sum = nums[left] + nums[right]
        if current_sum == target:
            return [left + 1, right + 1]
        elif current_sum < target:
            left += 1
        else:
            right -= 1
    return []
# Out:
# True

# %%
def containsDuplicate(nums):
    num_set = set()
    for num in nums:
        if num in num_set:
            return True
        num_set.add(num)
    return False


nums = [1, 2, 3, 4, 5]

print(containsDuplicate(nums))
# Out:
# False

# %%
class Solution:
    def nextLargerElement(self, arr):
        
        out_put = []
        
        j = 1

        for i in range(0,len(arr)-1):            
            
            
            if arr[i] < arr[j]:
                out_put.append(arr[j])

                if j == len(arr)-1:
                    out_put.append(-1)    
            
            else:
                out_put.append(-1)

            j+=1

                
        print(out_put)
        
obj = Solution()
obj.nextLargerElement([1, 3, 2, 4])
# Out:
# [3, -1, 4, -1]

# %%
#Next Greater Element in Array

class Solution:
    def nextLargerElement(self, arr):
        
        out_put = []
        
        j = 1

        for i in range(0,len(arr)-1):
            
            if  j == len(arr)-1:
                 out_put.append(-1)    
            
            
            elif arr[i] < arr[j]:
                out_put.append(arr[j])
            else:
                out_put.append(-1)
            j+=1    
        

obj = Solution()
obj.nextLargerElement([1, 3, 2, 4])

# %%
class Solution:
    def nextLargerElement(self, arr):

        out_put = []

        for i in range(0,len(arr)):

            found = False

            for j in range(i+1, len(arr)):

                if arr[j] >  arr[i]:
                    out_put.append(arr[j])
                    found = True
                    break

            if not found:
                out_put.append(-1)

        print(out_put)

obj = Solution()
obj.nextLargerElement([6, 8, 0, 1, 3])
# Out:
# [8, -1, 1, 3, -1]

# %%
a = 2
b = 3
print(a+++b)
# Out:
# 5

# %%
c= 'A'



print(c)
# Out:
# A

# %%
def nextGreaterElement(nums1, nums2):
    next_greater = {}
    stack = []

    for num in nums2:
        while stack and stack[-1] < num:
            next_greater[stack.pop()] = num
        stack.append(num)

    while stack:
        next_greater[stack.pop()] = -1

    return [next_greater[num] for num in nums1]

nums1 = [3,1,2]

nums2 = [1,3,4,2]

print(nextGreaterElement(nums1, nums2))
# Out:
# [4, 3, -1]
